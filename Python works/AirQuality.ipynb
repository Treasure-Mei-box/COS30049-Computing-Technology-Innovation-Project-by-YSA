# %%
import pandas as pd

file_path = "/content/drive/MyDrive/AQIs/langkawi,-kedah-air-quality.csv"
df = pd.read_csv(file_path)

# Clean column names
df.columns = df.columns.str.strip().str.replace(" ", "_")

# Keep only Date & AQI columns (if names differ, print df.columns to check)
df = df[['date', 'aqi']]

# Convert Date to datetime
df['date'] = pd.to_datetime(df['date'], errors='coerce')

# Filter only 2014–2024
df = df[df['date'].dt.year.between(2014, 2024)]

# Sort ascending by date (oldest → newest)
df = df.sort_values('date')

# Save cleaned file
cleaned_path = "/content/drive/MyDrive/AQIs/langkawi_cleaned_2014_2024.csv"
df.to_csv(cleaned_path, index=False)

print("✅ Cleaned data saved to:", cleaned_path)
print(df.head())
# Out:
# ✅ Cleaned data saved to: /content/drive/MyDrive/AQIs/langkawi_cleaned_2014_2024.csv
#            date  aqi
# 3852 2014-01-01   47
# 3853 2014-01-02   38
# 3854 2014-01-03   33
# 3855 2014-01-04   30
# 3856 2014-01-05   36

# %%
import pandas as pd

file_path = "/content/drive/MyDrive/AQIs/larkin-lama, johor-air-quality.csv"
df = pd.read_csv(file_path)

# Clean column names
df.columns = df.columns.str.strip().str.replace(" ", "_")

df = df[['date', 'aqi']]

# Convert Date to datetime
df['date'] = pd.to_datetime(df['date'], errors='coerce')

# Filter only 2014–2024
df = df[df['date'].dt.year.between(2014, 2024)]

# Sort ascending by date (oldest → newest)
df = df.sort_values('date')

# Save cleaned file
cleaned_path = "/content/drive/MyDrive/AQIs/LarkinJohor.csv"
df.to_csv(cleaned_path, index=False)

print("✅ Cleaned data saved to:", cleaned_path)
print(df.head())
# Out:
# ✅ Cleaned data saved to: /content/drive/MyDrive/AQIs/LarkinJohor.csv
#            date  aqi
# 3862 2014-01-01   35
# 3863 2014-01-02   39
# 3864 2014-01-03   37
# 3865 2014-01-04   28
# 3866 2014-01-05   25

# %%
import pandas as pd

file_path = "/content/drive/MyDrive/AQIs/miri-air-quality.csv"
df = pd.read_csv(file_path)

# Clean column names
df.columns = df.columns.str.strip().str.replace(" ", "_")
df = df[['date', 'aqi']]

# Convert Date to datetime
df['date'] = pd.to_datetime(df['date'], errors='coerce')

# Filter only 2014–2024
df = df[df['date'].dt.year.between(2014, 2024)]

# Sort ascending by date (oldest → newest)
df = df.sort_values('date')

# Save cleaned file
cleaned_path = "/content/drive/MyDrive/AQIs/Miri.csv"
df.to_csv(cleaned_path, index=False)

print("✅ Cleaned data saved to:", cleaned_path)
print(df.head())
# Out:
# ✅ Cleaned data saved to: /content/drive/MyDrive/AQIs/Miri.csv
#            date  aqi
# 3852 2014-01-01   20
# 3853 2014-01-02   18
# 3854 2014-01-03   19
# 3855 2014-01-04   15
# 3856 2014-01-05   18

# %%
import pandas as pd

file_path = "/content/drive/MyDrive/AQIs/nilai,-negeri sembilan-air-quality.csv"
df = pd.read_csv(file_path)

# Clean column names
df.columns = df.columns.str.strip().str.replace(" ", "_")

df = df[['date', 'aqi']]

# Convert Date to datetime
df['date'] = pd.to_datetime(df['date'], errors='coerce')

# Filter only 2014–2024
df = df[df['date'].dt.year.between(2014, 2024)]

# Sort ascending by date (oldest → newest)
df = df.sort_values('date')

# Save cleaned file
cleaned_path = "/content/drive/MyDrive/AQIs/Nilai.csv"
df.to_csv(cleaned_path, index=False)

print("✅ Cleaned data saved to:", cleaned_path)
print(df.head())
# Out:
# ✅ Cleaned data saved to: /content/drive/MyDrive/AQIs/Nilai.csv
#            date  aqi
# 3855 2014-01-01   28
# 3856 2014-01-02   26
# 3857 2014-01-03   33
# 3858 2014-01-04   37
# 3859 2014-01-05   47

# %%
import pandas as pd

file_path = "/content/drive/MyDrive/AQIs/port-dickson, negeri sembilan-air-quality.csv"
df = pd.read_csv(file_path)

# Clean column names
df.columns = df.columns.str.strip().str.replace(" ", "_")
df = df[['date', 'aqi']]

# Convert Date to datetime
df['date'] = pd.to_datetime(df['date'], errors='coerce')

# Filter only 2014–2024
df = df[df['date'].dt.year.between(2014, 2024)]

# Sort ascending by date (oldest → newest)
df = df.sort_values('date')

# Save cleaned file
cleaned_path = "/content/drive/MyDrive/AQIs/PortDickson.csv"
df.to_csv(cleaned_path, index=False)

print("✅ Cleaned data saved to:", cleaned_path)
print(df.head())
# Out:
# ✅ Cleaned data saved to: /content/drive/MyDrive/AQIs/PortDickson.csv
#            date  aqi
# 3861 2014-01-01   33
# 3862 2014-01-02   32
# 3863 2014-01-03   36
# 3864 2014-01-04   31
# 3865 2014-01-05   36

# %%
import pandas as pd

file_path = "/content/drive/MyDrive/AQIs/petaling-jaya, selangor-air-quality.csv"
df = pd.read_csv(file_path)

# Clean column names
df.columns = df.columns.str.strip().str.replace(" ", "_")
df = df[['date', 'aqi']]

# Convert Date to datetime
df['date'] = pd.to_datetime(df['date'], errors='coerce')

# Filter only 2014–2024
df = df[df['date'].dt.year.between(2014, 2024)]

# Sort ascending by date (oldest → newest)
df = df.sort_values('date')

# Save cleaned file
cleaned_path = "/content/drive/MyDrive/AQIs/PetalingJaya.csv"
df.to_csv(cleaned_path, index=False)

print("✅ Cleaned data saved to:", cleaned_path)
print(df.head())
df = pd.read_csv(file_path)
# Out:
#   File "/tmp/ipython-input-1647435167.py", line 25
#     .csv"
#         ^
# SyntaxError: unterminated string literal (detected at line 25)

# %%
import pandas as pd

file_path = "/content/drive/MyDrive/AQIs/s-k jalan pegoh, ipoh, perak-air-quality.csv"
df = pd.read_csv(file_path)

# Clean column names
df.columns = df.columns.str.strip().str.replace(" ", "_")
df = df[['date', 'aqi']]

# Convert Date to datetime
df['date'] = pd.to_datetime(df['date'], errors='coerce')

# Filter only 2014–2024
df = df[df['date'].dt.year.between(2014, 2024)]

# Sort ascending by date (oldest → newest)
df = df.sort_values('date')

# Save cleaned file
cleaned_path = "/content/drive/MyDrive/AQIs/Sandakan.csv"
df.to_csv(cleaned_path, index=False)

print("✅ Cleaned data saved to:", cleaned_path)
print(df.head())
# Out:
# ✅ Cleaned data saved to: /content/drive/MyDrive/AQIs/Sandakan.csv
#            date  aqi
# 3765 2014-01-01   46
# 3766 2014-01-02   41
# 3767 2014-01-03   34
# 3768 2014-01-04   43
# 3769 2014-01-05   40

# %%
import pandas as pd

file_path = "/content/drive/MyDrive/AQIs/seremban,-negeri sembilan-air-quality.csv"
df = pd.read_csv(file_path)

# Clean column names
df.columns = df.columns.str.strip().str.replace(" ", "_")
df = df[['date', 'aqi']]

# Convert Date to datetime
df['date'] = pd.to_datetime(df['date'], errors='coerce')

# Filter only 2014–2024
df = df[df['date'].dt.year.between(2014, 2024)]

# Sort ascending by date (oldest → newest)
df = df.sort_values('date')

# Save cleaned file
cleaned_path = "/content/drive/MyDrive/AQIs/Seremban.csv"
df.to_csv(cleaned_path, index=False)

print("✅ Cleaned data saved to:", cleaned_path)
print(df.head())
# Out:
# ✅ Cleaned data saved to: /content/drive/MyDrive/AQIs/Seremban.csv
#            date  aqi
# 3857 2014-01-01   29
# 3858 2014-01-02   27
# 3859 2014-01-03   30
# 3860 2014-01-04   23
# 3861 2014-01-05   26

# %%
import pandas as pd

file_path = "/content/drive/MyDrive/AQIs/shah-alam, selangor-air-quality.csv"
df = pd.read_csv(file_path)

# Clean column names
df.columns = df.columns.str.strip().str.replace(" ", "_")
df = df[['date', 'aqi']]

# Convert Date to datetime
df['date'] = pd.to_datetime(df['date'], errors='coerce')

# Filter only 2014–2024
df = df[df['date'].dt.year.between(2014, 2024)]

# Sort ascending by date (oldest → newest)
df = df.sort_values('date')

# Save cleaned file
cleaned_path = "/content/drive/MyDrive/AQIs/ShahAlam.csv"
df.to_csv(cleaned_path, index=False)

print("✅ Cleaned data saved to:", cleaned_path)
print(df.head())
# Out:
# ✅ Cleaned data saved to: /content/drive/MyDrive/AQIs/ShahAlam.csv
#            date  aqi
# 3844 2014-01-01   53
# 3845 2014-01-02   48
# 3846 2014-01-03   40
# 3847 2014-01-04   30
# 3848 2014-01-05   41

# %%
import pandas as pd

file_path = "/content/drive/MyDrive/AQIs/sibu,-sarawak-air-quality.csv"
df = pd.read_csv(file_path)

# Clean column names
df.columns = df.columns.str.strip().str.replace(" ", "_")
df = df[['date', 'aqi']]

# Convert Date to datetime
df['date'] = pd.to_datetime(df['date'], errors='coerce')

# Filter only 2014–2024
df = df[df['date'].dt.year.between(2014, 2024)]

# Sort ascending by date (oldest → newest)
df = df.sort_values('date')

# Save cleaned file
cleaned_path = "/content/drive/MyDrive/AQIs/Sibu.csv"
df.to_csv(cleaned_path, index=False)

print("✅ Cleaned data saved to:", cleaned_path)
print(df.head())
# Out:
# ✅ Cleaned data saved to: /content/drive/MyDrive/AQIs/Sibu.csv
#            date  aqi
# 3864 2014-01-01   22
# 3865 2014-01-02   12
# 3866 2014-01-03   16
# 3867 2014-01-04   17
# 3868 2014-01-05   17
